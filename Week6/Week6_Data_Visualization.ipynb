# %% [markdown]
# # Week 6: IoT Data Visualization
#
# ## Objective
# To create visualizations for an IoT sensor dataset using Matplotlib, Seaborn, and Plotly. An interactive dashboard prototype is also developed to analyze temperature and humidity trends.
#
# ## Libraries Used
# - Pandas
# - Matplotlib
# - Seaborn
# - Plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("Better_Dataset.csv")

df.head()
# Out:
#                   date  temperature   humidity  verdict
# 0  2024-03-01 00:00:00    24.912950  36.451926        1
# 1  2024-03-01 04:00:00    31.259358  50.668960        0
# 2  2024-03-01 08:00:00    29.988245  55.987899        0
# 3  2024-03-01 12:00:00    35.314738  56.160208        0
# 4  2024-03-01 16:00:00    26.163837  48.280121        1

# %%
df["date"] = pd.to_datetime(df["date"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2311 non-null   datetime64[ns]
#  1   temperature  2311 non-null   float64
#  2   humidity     2311 non-null   float64
#  3   verdict      2311 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 72.3 KB

# %%
plt.figure(figsize=(12,5))

plt.plot(df["date"], df["temperature"])

plt.title("Temperature Over Time")

plt.xlabel("Date")

plt.ylabel("Temperature (°C)")

plt.xticks(rotation=45)

plt.show()

# %%
monthly_temp = df.groupby(df["date"].dt.month)["temperature"].mean()

plt.figure(figsize=(10,5))

monthly_temp.plot(kind="bar")

plt.title("Average Monthly Temperature")

plt.xlabel("Month")

plt.ylabel("Average Temperature (°C)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df[["temperature","humidity"]])

plt.title("Temperature and Humidity Distribution")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
fig = px.line(
    df,
    x="date",
    y=["temperature", "humidity"],
    title="Interactive Temperature and Humidity Dashboard"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Week 6: IoT Data Visualization
#
# ## Objective
# To create meaningful visualizations for an IoT sensor dataset using Matplotlib, Seaborn, and Plotly. The notebook demonstrates different visualization techniques and an interactive dashboard prototype.
#
# ## Tools Used
# - Python
# - Google Colab
# - Pandas
# - Matplotlib
# - Seaborn
# - Plotly

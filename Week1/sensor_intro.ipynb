# %% [markdown]
# # IoT Sensor Data Analysis
#
# This notebook demonstrates basic IoT sensor readings using Python.
#
# **Intern:** Saniya Syed
#
# **Week 1 – IoT Fundamentals**

# %%
temperature = 27.5
humidity = 68

print("Temperature:", temperature, "°C")
print("Humidity:", humidity, "%")
# Out:
# Temperature: 27.5 °C
# Humidity: 68 %

# %%
if temperature > 30:
    print("High Temperature")
else:
    print("Temperature is Normal")
# Out:
# Temperature is Normal

# %%
sensor_data = {
    "Temperature": "27.5 °C",
    "Humidity": "68%",
    "Pressure": "1012 hPa"
}

for key, value in sensor_data.items():
    print(f"{key}: {value}")
# Out:
# Temperature: 27.5 °C
# Humidity: 68%
# Pressure: 1012 hPa

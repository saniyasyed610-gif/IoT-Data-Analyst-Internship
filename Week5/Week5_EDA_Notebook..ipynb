# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Imported Successfully!")
# Out:
# Libraries Imported Successfully!

# %%
df = pd.read_csv("Better_Dataset.csv")

df.head()
# Out:
#                   date  temperature   humidity  verdict
# 0  2024-03-01 00:00:00    24.912950  36.451926        1
# 1  2024-03-01 04:00:00    31.259358  50.668960        0
# 2  2024-03-01 08:00:00    29.988245  55.987899        0
# 3  2024-03-01 12:00:00    35.314738  56.160208        0
# 4  2024-03-01 16:00:00    26.163837  48.280121        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2311 non-null   object
#  1   temperature  2311 non-null   float64
#  2   humidity     2311 non-null   float64
#  3   verdict      2311 non-null   int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 72.3+ KB

# %%
df.describe()
# Out:
#        temperature     humidity      verdict
# count  2311.000000  2311.000000  2311.000000
# mean     27.003090    53.069079     0.302034
# std       7.558388    14.306975     0.459239
# min       9.672369     0.000000     0.000000
# 25%      21.586704    43.870155     0.000000
# 50%      25.985870    53.944031     0.000000
# 75%      31.644917    63.679985     1.000000
# max      58.443347    95.429325     1.000000

# %%
df.isnull().sum()
# Out:
# date           0
# temperature    0
# humidity       0
# verdict        0
# dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %%
df.hist(figsize=(8,6))
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df[["temperature","humidity"]])

plt.title("Temperature and Humidity Distribution")

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.scatterplot(
    x="temperature",
    y="humidity",
    data=df
)

plt.title("Temperature vs Humidity")

plt.show()

# %%
df["date"] = pd.to_datetime(df["date"])

plt.figure(figsize=(12,5))

plt.plot(df["date"], df["temperature"])

plt.title("Temperature Over Time")

plt.xlabel("Date")

plt.ylabel("Temperature")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(12,5))

plt.plot(df["date"], df["temperature"], label="Temperature")

plt.plot(df["date"], df["humidity"], label="Humidity")

plt.legend()

plt.title("Temperature and Humidity Over Time")

plt.xticks(rotation=45)

plt.show()
